# %% [markdown]
# #2021 Sigradi workshop
# #Deep Architecture: Using AI in Architecture
# ##Instructor: Mohammed Behjoo
# https://linktr.ee/MohammedBehjoo

# %% [markdown]
# ## 1. synicing GDrive and Colab and importing required libraries

# %% [markdown]
# ### 1. Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2.libraries

# %% [markdown]
#  importing and listalling required libraries

# %%
# %tensorflow_version 1.x
import tensorflow as tf

# %% [markdown]
# ## 2. preprocessing data phase

# %% [markdown]
# ### 2-1. resizing images

# %%
path_to_resize = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern" #@param {type:"string"}
resize_output_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern" #@param {type:"string"}
resize_resolution = 1024 #@param {type:"integer"}

#import dependencies 
from PIL import Image
import os, sys#set file path
path = path_to_resize
dirs = os.listdir( path )
def resize():
    print(path_to_resize)
    #loop through the images
    for item in dirs:
        if os.path.isfile(path+"/"+item):
            im = Image.open(path+"/"+item)
            f, e = os.path.splitext(path+"/"+item)
            print(f)
            #set the output size: 256,256 or 512,512 or 1024,1024
            imResize = im.resize((resize_resolution,resize_resolution), Image.ANTIALIAS)
            
            #save the images as image name + JPEG
            imResize.save(resize_output_path + '/' + item)
resize()
# Out:
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000062
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000063
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000064
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000065
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000066
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000067
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000068
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000069
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000070
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000071
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000072
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000073
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000074
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000075
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000076
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000077
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000078
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000079
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000080
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000097
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000098
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000107
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000108
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000109
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000110
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000111
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000112
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000113
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000128
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000129
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000130
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000131
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000132
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000133
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000134
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000135
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000136
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000141
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000142
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000143
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000144
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000153
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000154
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000159
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000160
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000162
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000163
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000180
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000181
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000182
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000183
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000184
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000185
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000186
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000190
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000191
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000192
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000193
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000194
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000195
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000196
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000200
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000201
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000202
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000203
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000204
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000205
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000206
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000207
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000208
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000209
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000210
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000211
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000212
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000213
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000214
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000215
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000216
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000217
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000218
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000219
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000220
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000221
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000222
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000223
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000224
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000225
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000226
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000227
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000228
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000229
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000230
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000231
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000232
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000233
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000234
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000235
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000236
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000237
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000238
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000239
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000240
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000241
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000242
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000243
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000244
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000245
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000246
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000247
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000248
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000249
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000250
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000251
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000252
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000253
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000254
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000255
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000256
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000257
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000258
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000259
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000260
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000261
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000262
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000263
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000264
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000265
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000266
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000267
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000268
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000269
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000270
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000271
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000272
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000273
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000274
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000275
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000276
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000277
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000278
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000279
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000280
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000281
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000282
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000283
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000284
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000285
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000286
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000287
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000288
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000289
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000290
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000291
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000292
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000293
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000294
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000295
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000296
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000297
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000298
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000299
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000300
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000301
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000302
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000303
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000304
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000305
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000306
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000307
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000308
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000309
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000310
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000311
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000312
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000313
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000314
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000315
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000316
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000317
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000318
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000319
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000320
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000321
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000322
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000323
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000324
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000325
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000326
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000327
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000328
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000329
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000330
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000331
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000332
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000333
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000334
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000335
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000336
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000337
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000338
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000339
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000340
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000341
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000342
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000343
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000344
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000345
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000346
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000347
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000348
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000349
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000350
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000351
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000352
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000353
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000354
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000355
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000356
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000357
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000358
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000359
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000360
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000361
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000362
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000363
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000364
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000365
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000366
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000367
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000368
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000369
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000370
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000371
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000372
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000373
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000374
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000375
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000376
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000377
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000378
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000379
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000380
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000381
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000382
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000383
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000384
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000385
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000386
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000387
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000388
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000389
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000390
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000391
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000392
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000393
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000394
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000395
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000396
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000397
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000398
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000399
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000400
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000401
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000402
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000403
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000404
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000405
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000406
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000407
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000408
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000409
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000410
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000411
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000412
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000413
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000414
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000415
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000416
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000417
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000418
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000419
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000420
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000421
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000422
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000423
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000424
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000425
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000426
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000427
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000428
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000429
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000430
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000431
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000432
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000433
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000434
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000435
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000436
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000437
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000438
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000439
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000440
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000441
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000442
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000443
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000444
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000445
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000446
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000447
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000448
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000449
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000450
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000451
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000452
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000453
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000454
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000455
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000456
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000457
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000458
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000459
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000460
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000461
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000462
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000463
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000464
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000465
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000466
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000467
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000468
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000469
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000470
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000471
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000472
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000473
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000474
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000475
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000476
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000477
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000478
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000479
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000480
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000481
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000482
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000483
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000484
# ...
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000024
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000026
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000025
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000027
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000028
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000029
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000030
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000033
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000032
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000031
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000034
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000040
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000037
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000036
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000038
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000035
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000039
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000041
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000042
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000043
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000044
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000049
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000045
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000047
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000046
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000050
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000048
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000051
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000052
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000053
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000054
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000055
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000056
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000057
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000058
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000059
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000060
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000061
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000082
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000081
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000083
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000084
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000087
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000086
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000085
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000088
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000089
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000090
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000092
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000091
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000093
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000094
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000095
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000096
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000099
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000100
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000101
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000102
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000103
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000104
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000105
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000106
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000115
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000114
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000116
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000117
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000118
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000119
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000120
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000121
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000122
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000124
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000125
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000123
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000126
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000127
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000137
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000139
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000138
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000140
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000145
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000146
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000147
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000148
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000149
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000151
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000152
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000150
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000155
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000156
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000157
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000158
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000161
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000164
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000165
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000166
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000167
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000168
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000169
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000170
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000171
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000172
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000174
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000173
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000176
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000175
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000177
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000187
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000179
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000178
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000197
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000189
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000198
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000188
# /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000199

# %% [markdown]
# ### 2-2.renaming the files

# %%
import os
import re

path_to_rename_files = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern" #@param {type:"string"}

files = os.listdir(path_to_rename_files)
files.sort(key=lambda r:r[0])
n = 0

for file in files:

  n+=1
  os.rename(os.path.join(path_to_rename_files, file), os.path.join(path_to_rename_files, ""+'{:09d}'.format(0 + n)+'.' + 'png'))
   
print("finished")
# Out:
# finished

# %% [markdown]
# ### 2-3. convert every image extension file to JPG

# %%
to_JPG = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern" #@param {type:"string"}
#importing the required package
from PIL import Image, ImageFile
import os, sys

def convert():
    print(to_JPG)
    ext = ''
    for root, dirs, item in os.walk(to_JPG):
        print("root_" + root)
        #print("dir_" + dirs)
        #print(item)
        
        files = os.listdir( root )
        
        for item in files:
            #print(root+item)
            print("---")
            print("---")
            if os.path.isfile(root+"/"+item):
                 if item.endswith(".png"):
                    img = Image.open(root+"/"+item)
                    f, e = os.path.splitext(root+"/"+item)
                    #print(f)
                    #print(e)
                    print(item)
                    ext = e
                    if ext=='.png' and img.mode != 'I' and img.mode != 'LA' and img.mode != 'P':
                        if img.mode == 'RGBA':
                            img = img.convert('RGB')
                        img.save(f + ".jpg")
                        print("saved   - " + f + '.jpg')
                        os.remove(f+e)
                        print("removed - " + f + e)
convert()
# Out:
# Streaming output truncated to the last 5000 lines.
# 000000554.png
# saved   - /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000554.jpg
# removed - /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000554.png
# ---
# ---
# 000000555.png
# saved   - /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000555.jpg
# removed - /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000555.png
# ---
# ---
# 000000556.png
# saved   - /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000556.jpg
# removed - /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000556.png
# ---
# ---
# root_/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/000000557.png
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ### 2-4. Mode conversion

# %%
from PIL import Image, ImageFile
import os, sys
import argparse
import cv2

images_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern" #@param {type:"string"}
coversion_mode = "RGB" #@param {type:"string"}

dirs = os.listdir( images_path )

def convertMode(input_p, convertMode):
  print('convertMode')
  for item in dirs:
    #print(item)

    if os.path.isfile(input_p+"/"+item):
      im = Image.open(input_p+"/"+item)
      f, e = os.path.splitext(input_p+"/"+item)
      print(item)

      if convertMode == 'CMYK':
        if im.mode == 'RGB' or im.mode == 'RGBA'  or im.mode == 'LAB' or im.mode == 'HSV' or im.mode == 'YCbCr' or im.mode == 'RGBX' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('CMYK')
          im = im.convert('CMYK')
          print(item + "--converted")
            
      if convertMode == 'RGB':
        if im.mode == 'CMYK' or im.mode == 'RGBA'  or im.mode == 'LAB' or im.mode == 'HSV' or im.mode == 'YCbCr' or im.mode == 'RGBX' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('RGB')
          im = im.convert('RGB')
          print(item + "--converted")

      if convertMode == 'RGBA':                
        if im.mode == 'CMYK' or im.mode == 'RGB'  or im.mode == 'LAB' or im.mode == 'HSV' or im.mode == 'YCbCr' or im.mode == 'RGBX' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('RGBA')
          im = im.convert('RGBA')
          print(item + "--converted")
            
      if convertMode == 'LAB': 
        if im.mode == 'CMYK' or im.mode == 'RGB'  or im.mode == 'RGBA' or im.mode == 'HSV' or im.mode == 'YCbCr' or im.mode == 'RGBX' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('LAB')
          im = im.convert('LAB')
          print(item + "--converted")
            
      if convertMode == 'HSV': 
        if im.mode == 'CMYK' or im.mode == 'RGB'  or im.mode == 'RGBA' or im.mode == 'LAB' or im.mode == 'YCbCr' or im.mode == 'RGBX' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('HSV')
          im = im.convert('HSV')
          print(item + "--converted")
               
      if convertMode == 'YCbCr': 
        if im.mode == 'CMYK' or im.mode == 'RGB'  or im.mode == 'RGBA' or im.mode == 'LAB' or im.mode == 'HSV' or im.mode == 'RGBX' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('YCbCr')
          im = im.convert('YCbCr')
          print(item + "--converted")
            
      if convertMode == 'YCbCr': 
        if im.mode == 'CMYK' or im.mode == 'RGB'  or im.mode == 'RGBA' or im.mode == 'LAB' or im.mode == 'HSV' or im.mode == 'YCbCr' or im.mode == 'RGBa'    :
          print("mode found")
          #im = im.convert('RGBX')
          im = im.convert('RGBX')
          print(item + "--converted")

      if convertMode == 'RGBa':                
        if im.mode == 'CMYK' or im.mode == 'RGB'  or im.mode == 'RGBA' or im.mode == 'LAB' or im.mode == 'HSV' or im.mode == 'YCbCr' or im.mode == 'RGBX'    :
          print("mode found")
          #im = im.convert('RGBa')
          im = im.convert('RGBa')
          print(item + "--converted")

convertMode(images_path, coversion_mode)
# Out:
# convertMode
# 000000062.jpg
# 000000063.jpg
# 000000064.jpg
# 000000065.jpg
# 000000066.jpg
# 000000067.jpg
# 000000068.jpg
# 000000069.jpg
# 000000070.jpg
# 000000071.jpg
# 000000072.jpg
# 000000073.jpg
# 000000074.jpg
# 000000075.jpg
# 000000076.jpg
# 000000077.jpg
# 000000078.jpg
# 000000079.jpg
# 000000080.jpg
# 000000097.jpg
# 000000098.jpg
# 000000107.jpg
# 000000108.jpg
# 000000109.jpg
# 000000110.jpg
# 000000111.jpg
# 000000112.jpg
# 000000113.jpg
# 000000128.jpg
# 000000129.jpg
# 000000130.jpg
# 000000131.jpg
# 000000132.jpg
# 000000133.jpg
# 000000134.jpg
# 000000135.jpg
# 000000136.jpg
# 000000141.jpg
# 000000142.jpg
# 000000143.jpg
# 000000144.jpg
# 000000153.jpg
# 000000154.jpg
# 000000159.jpg
# 000000160.jpg
# 000000162.jpg
# 000000163.jpg
# 000000180.jpg
# 000000181.jpg
# 000000182.jpg
# 000000183.jpg
# 000000184.jpg
# 000000185.jpg
# 000000186.jpg
# 000000190.jpg
# 000000191.jpg
# 000000192.jpg
# 000000193.jpg
# 000000194.jpg
# 000000195.jpg
# 000000196.jpg
# 000000200.jpg
# 000000201.jpg
# 000000202.jpg
# 000000203.jpg
# 000000204.jpg
# 000000205.jpg
# 000000206.jpg
# 000000207.jpg
# 000000208.jpg
# 000000209.jpg
# 000000210.jpg
# 000000211.jpg
# 000000212.jpg
# 000000213.jpg
# 000000214.jpg
# 000000215.jpg
# 000000216.jpg
# 000000217.jpg
# 000000218.jpg
# 000000219.jpg
# 000000220.jpg
# 000000221.jpg
# 000000222.jpg
# 000000223.jpg
# 000000224.jpg
# 000000225.jpg
# 000000226.jpg
# 000000227.jpg
# 000000228.jpg
# 000000229.jpg
# 000000230.jpg
# 000000231.jpg
# 000000232.jpg
# 000000233.jpg
# 000000234.jpg
# 000000235.jpg
# 000000236.jpg
# 000000237.jpg
# 000000238.jpg
# 000000239.jpg
# 000000240.jpg
# 000000241.jpg
# 000000242.jpg
# 000000243.jpg
# 000000244.jpg
# 000000245.jpg
# 000000246.jpg
# 000000247.jpg
# 000000248.jpg
# 000000249.jpg
# 000000250.jpg
# 000000251.jpg
# 000000252.jpg
# 000000253.jpg
# 000000254.jpg
# 000000255.jpg
# 000000256.jpg
# 000000257.jpg
# 000000258.jpg
# 000000259.jpg
# 000000260.jpg
# 000000261.jpg
# 000000262.jpg
# 000000263.jpg
# 000000264.jpg
# 000000265.jpg
# 000000266.jpg
# 000000267.jpg
# 000000268.jpg
# 000000269.jpg
# 000000270.jpg
# 000000271.jpg
# 000000002.jpg
# 000000001.jpg
# 000000003.jpg
# 000000004.jpg
# 000000005.jpg
# 000000007.jpg
# 000000006.jpg
# 000000008.jpg
# 000000010.jpg
# 000000013.jpg
# 000000011.jpg
# 000000012.jpg
# 000000009.jpg
# 000000014.jpg
# 000000017.jpg
# 000000016.jpg
# 000000015.jpg
# 000000018.jpg
# 000000021.jpg
# 000000019.jpg
# 000000022.jpg
# 000000020.jpg
# 000000023.jpg
# 000000024.jpg
# 000000026.jpg
# 000000025.jpg
# 000000027.jpg
# 000000028.jpg
# 000000029.jpg
# 000000030.jpg
# 000000033.jpg
# 000000032.jpg
# 000000031.jpg
# 000000034.jpg
# 000000040.jpg
# 000000037.jpg
# 000000036.jpg
# 000000038.jpg
# 000000035.jpg
# 000000039.jpg
# 000000041.jpg
# 000000042.jpg
# 000000043.jpg
# 000000044.jpg
# 000000049.jpg
# 000000045.jpg
# 000000047.jpg
# 000000046.jpg
# 000000050.jpg
# 000000048.jpg
# 000000051.jpg
# 000000052.jpg
# 000000053.jpg
# 000000054.jpg
# 000000055.jpg
# 000000056.jpg
# 000000057.jpg
# 000000058.jpg
# 000000059.jpg
# 000000060.jpg
# 000000061.jpg
# 000000082.jpg
# 000000081.jpg
# 000000083.jpg
# 000000084.jpg
# 000000087.jpg
# 000000086.jpg
# 000000085.jpg
# 000000088.jpg
# 000000089.jpg
# 000000090.jpg
# 000000092.jpg
# 000000091.jpg
# 000000093.jpg
# 000000094.jpg
# 000000095.jpg
# 000000096.jpg
# 000000099.jpg
# 000000100.jpg
# 000000101.jpg
# 000000102.jpg
# 000000103.jpg
# 000000104.jpg
# 000000105.jpg
# 000000106.jpg
# 000000115.jpg
# 000000114.jpg
# 000000116.jpg
# 000000117.jpg
# 000000118.jpg
# 000000119.jpg
# 000000120.jpg
# 000000121.jpg
# 000000122.jpg
# 000000124.jpg
# 000000125.jpg
# 000000123.jpg
# 000000126.jpg
# 000000127.jpg
# 000000137.jpg
# 000000139.jpg
# 000000138.jpg
# 000000140.jpg
# 000000145.jpg
# 000000146.jpg
# 000000147.jpg
# 000000148.jpg
# 000000149.jpg
# 000000151.jpg
# 000000152.jpg
# 000000150.jpg
# 000000155.jpg
# 000000156.jpg
# 000000157.jpg
# 000000158.jpg
# 000000161.jpg
# 000000164.jpg
# 000000165.jpg
# 000000166.jpg
# 000000167.jpg
# 000000168.jpg
# 000000169.jpg
# 000000170.jpg
# 000000171.jpg
# 000000172.jpg
# 000000174.jpg
# 000000173.jpg
# 000000176.jpg
# 000000175.jpg
# 000000177.jpg
# 000000187.jpg
# 000000179.jpg
# 000000178.jpg
# 000000197.jpg
# 000000189.jpg
# 000000198.jpg
# 000000188.jpg
# 000000199.jpg
# 000000272.jpg
# 000000273.jpg
# 000000274.jpg
# 000000275.jpg
# 000000276.jpg
# 000000277.jpg
# 000000278.jpg
# 000000279.jpg
# 000000280.jpg
# 000000281.jpg
# 000000282.jpg
# 000000283.jpg
# 000000284.jpg
# 000000285.jpg
# 000000286.jpg
# 000000287.jpg
# 000000288.jpg
# 000000289.jpg
# 000000290.jpg
# 000000291.jpg
# 000000292.jpg
# 000000293.jpg
# 000000294.jpg
# 000000295.jpg
# 000000296.jpg
# 000000297.jpg
# 000000298.jpg
# 000000299.jpg
# 000000300.jpg
# 000000301.jpg
# 000000302.jpg
# 000000303.jpg
# 000000304.jpg
# 000000305.jpg
# 000000306.jpg
# 000000307.jpg
# 000000308.jpg
# 000000309.jpg
# 000000310.jpg
# 000000311.jpg
# 000000312.jpg
# 000000313.jpg
# 000000314.jpg
# 000000315.jpg
# 000000316.jpg
# 000000317.jpg
# 000000318.jpg
# 000000319.jpg
# 000000320.jpg
# 000000321.jpg
# 000000322.jpg
# 000000323.jpg
# 000000324.jpg
# 000000325.jpg
# 000000326.jpg
# 000000327.jpg
# 000000328.jpg
# 000000329.jpg
# 000000330.jpg
# 000000331.jpg
# 000000332.jpg
# 000000333.jpg
# 000000334.jpg
# 000000335.jpg
# 000000336.jpg
# 000000337.jpg
# 000000338.jpg
# 000000339.jpg
# 000000340.jpg
# 000000341.jpg
# 000000342.jpg
# 000000343.jpg
# 000000344.jpg
# 000000345.jpg
# 000000346.jpg
# 000000347.jpg
# 000000348.jpg
# 000000349.jpg
# 000000350.jpg
# 000000351.jpg
# 000000352.jpg
# 000000353.jpg
# 000000354.jpg
# 000000355.jpg
# 000000356.jpg
# 000000357.jpg
# 000000358.jpg
# 000000359.jpg
# 000000360.jpg
# 000000361.jpg
# 000000362.jpg
# 000000363.jpg
# 000000364.jpg
# 000000365.jpg
# 000000366.jpg
# 000000367.jpg
# 000000368.jpg
# 000000369.jpg
# 000000370.jpg
# 000000371.jpg
# 000000372.jpg
# 000000373.jpg
# 000000374.jpg
# 000000375.jpg
# 000000376.jpg
# 000000377.jpg
# 000000378.jpg
# 000000379.jpg
# 000000380.jpg
# 000000381.jpg
# 000000382.jpg
# 000000383.jpg
# 000000384.jpg
# 000000385.jpg
# 000000386.jpg
# 000000387.jpg
# 000000388.jpg
# 000000389.jpg
# 000000390.jpg
# 000000391.jpg
# 000000392.jpg
# 000000393.jpg
# 000000394.jpg
# 000000395.jpg
# 000000396.jpg
# 000000397.jpg
# 000000398.jpg
# 000000399.jpg
# 000000400.jpg
# 000000401.jpg
# 000000402.jpg
# 000000403.jpg
# 000000404.jpg
# 000000405.jpg
# 000000406.jpg
# 000000407.jpg
# 000000408.jpg
# 000000409.jpg
# 000000410.jpg
# 000000411.jpg
# 000000412.jpg
# 000000413.jpg
# 000000414.jpg
# 000000415.jpg
# 000000416.jpg
# 000000417.jpg
# 000000418.jpg
# 000000419.jpg
# 000000420.jpg
# 000000421.jpg
# 000000422.jpg
# 000000423.jpg
# 000000424.jpg
# 000000425.jpg
# 000000426.jpg
# 000000427.jpg
# 000000428.jpg
# 000000429.jpg
# 000000430.jpg
# 000000431.jpg
# 000000432.jpg
# 000000433.jpg
# 000000434.jpg
# 000000435.jpg
# 000000436.jpg
# 000000437.jpg
# 000000438.jpg
# 000000439.jpg
# 000000440.jpg
# 000000441.jpg
# 000000442.jpg
# 000000443.jpg
# 000000444.jpg
# 000000445.jpg
# 000000446.jpg
# 000000447.jpg
# 000000448.jpg
# 000000449.jpg
# 000000450.jpg
# 000000451.jpg
# 000000452.jpg
# 000000453.jpg
# 000000454.jpg
# 000000455.jpg
# 000000456.jpg
# 000000457.jpg
# 000000458.jpg
# 000000459.jpg
# 000000460.jpg
# 000000461.jpg
# 000000462.jpg
# 000000463.jpg
# 000000464.jpg
# 000000465.jpg
# 000000466.jpg
# 000000467.jpg
# 000000468.jpg
# 000000469.jpg
# 000000470.jpg
# 000000471.jpg
# 000000472.jpg
# 000000473.jpg
# 000000474.jpg
# 000000475.jpg
# 000000476.jpg
# 000000477.jpg
# 000000478.jpg
# 000000479.jpg
# 000000480.jpg
# 000000481.jpg
# 000000482.jpg
# 000000483.jpg
# 000000484.jpg
# 000000485.jpg
# 000000486.jpg
# 000000487.jpg
# 000000488.jpg
# 000000489.jpg
# 000000490.jpg
# 000000491.jpg
# 000000492.jpg
# 000000493.jpg
# 000000494.jpg
# 000000495.jpg
# 000000496.jpg
# 000000497.jpg
# 000000498.jpg
# 000000499.jpg
# 000000500.jpg
# 000000501.jpg
# 000000502.jpg
# 000000503.jpg
# 000000504.jpg
# 000000505.jpg
# 000000506.jpg
# 000000507.jpg
# 000000508.jpg
# 000000509.jpg
# 000000510.jpg
# 000000511.jpg
# 000000512.jpg
# 000000513.jpg
# 000000514.jpg
# 000000515.jpg
# 000000516.jpg
# 000000517.jpg
# 000000518.jpg
# 000000519.jpg
# 000000520.jpg
# 000000521.jpg
# 000000522.jpg
# 000000523.jpg
# 000000524.jpg
# 000000525.jpg
# 000000526.jpg
# 000000527.jpg
# 000000528.jpg
# 000000529.jpg
# 000000530.jpg
# 000000531.jpg
# 000000532.jpg
# 000000533.jpg
# 000000534.jpg
# 000000535.jpg
# 000000536.jpg
# 000000537.jpg
# 000000538.jpg
# 000000539.jpg
# 000000540.jpg
# 000000541.jpg
# 000000542.jpg
# 000000543.jpg
# 000000544.jpg
# 000000545.jpg
# 000000546.jpg
# 000000547.jpg
# 000000548.jpg
# 000000549.jpg
# 000000550.jpg
# 000000551.jpg
# 000000552.jpg
# 000000553.jpg
# 000000554.jpg
# 000000555.jpg
# 000000556.jpg

# %% [markdown]
# ### 2-5.augmentation

# %%
# !pip install augmentor
import Augmentor

images_path =  "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern" #@param {type:"string"}

# Create a pipeline
p = Augmentor.Pipeline(images_path)

# Add some operations to an existing pipeline.
p.set_seed(0)

# CROP 
# 0.crop from 1400x900 to 900x900
# p.crop_by_size(probability=1.0, width=2160, height=2160, centre=False)
#p.crop_centre(probability=0.5, percentage_area=0.9)

# Resize
# 5.Resize 900x900 crop to 512x512
p.resize(probability=1.0, width=1024, height=1024, resample_filter=u'BICUBIC')

# Rotate
#p.rotate(probability=1.0,max_left_rotation = 5, max_right_rotation=5)
# Add a rotate90 operation to the pipeline:
#p.rotate90(probability=1)

#put all images in one folder and flip horizontally
p.flip_left_right(probability=0.8)

# Now we add a vertical flip operation to the pipeline:
#p.flip_top_bottom(probability=1)

# p.skew_left_right(probability=0.4,magnitude=0.3)

#p.skew_tilt(probability=0.5, magnitude=0.4)

#p.skew_top_bottom(probability=1, magnitude=0.4)

#p.skew_corner(probability=0.5, magnitude=0.4)

#p.skew(probability=0.5, magnitude=0.4)

#p.gaussian_distortion(probability=0.5, grid_width = 512, grid_height = 512, magnitude=0.4, corner="ul", method="out", mex=0.5, mey=0.5, sdx=0.05, sdy=0.05)

#p.histogram_equalisation(probability=1.0)

p.random_brightness(probability=0.8, min_factor=0.7, max_factor=1)

p.random_color(probability = 0.9, min_factor=0.5, max_factor=1)

p.random_contrast(probability=0.9, min_factor=0.7, max_factor=1)

#zoom image
p.zoom(probability=0.8, min_factor=0.5, max_factor=0.9)

#p.process()


# Here we sample 100,000 images from the pipeline.

# It is often useful to use scientific notation for specify large numbers with trailing zeros.
num_of_samples = int(1e4)

# Now we can sample from the pipeline:
p.sample(2500)
# Out:
# Requirement already satisfied: augmentor in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from augmentor) (4.62.3)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from augmentor) (1.19.5)
# Initialised with 556 image(s) found.
# Output directory set to /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FAEFBAC2590>: 100%|██████████| 2500/2500 [02:12<00:00, 18.93 Samples/s]

# %% [markdown]
# ### 2-6. verifying images

# %%
#@title Default title text
dataset_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/output" #@param {type:"string"}
import os
from fastai.vision import verify_images

verify_images(dataset_path, delete=True)
os.chdir(stylegan2_ada)

# %% [markdown]
# ### 2-7.Crateing  TF records

# %% [markdown]
# StyleGAN2-ADA requires the data be in the TFRecord file format

# %%
# %tensorflow_version 1.x
import tensorflow as tf
#@title Default title text
dataset_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/output" #@param {type:"string"}
custom_dataset_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/custom" #@param {type:"string"}


# !python dataset_tool.py create_from_images $custom_dataset_path $dataset_path
# Out:
# Loading images from "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/houses_apartments_modern/output"
# Creating dataset "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/custom"
# dataset_tool.py:96: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 2500 images.

# %% [markdown]
# ## 3. training the model

# %% [markdown]
# ### 3-1.StyleGAN2-ADA

# %%
#@title Default title text
stylegan_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada" #@param {type:"string"}
stylegan2_ada = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada" #@param {type:"string"}
base_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture" #@param {type:"string"}

import os
if os.path.isdir(stylegan_path) and not os.path.exists(stylegan_path):
    if not os.path.exists(stylegan2_ada):
        os.mkdir(stylegan2_ada)
    os.chdir(stylegan2_ada)
else:
    #install script
    os.chdir(base_path)
    
    if not os.path.exists(stylegan_path):
        os.mkdir(stylegan_path)
    os.chdir(stylegan_path)
    # !git clone https://github.com/dvschultz/stylegan2-ada
    os.chdir(stylegan2_ada)
    if not os.path.exists("downloads"):
        os.mkdir("downloads")
    if not os.path.exists("datasets"):
        os.mkdir("datasets")


print('Tensorflow version: {}'.format(tf.__version__) )
# !nvidia-smi 
print('GPU Identified at: {}'.format(tf.test.gpu_device_name()))
os.chdir(stylegan2_ada)
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git checkout origin/main -- train.py
# Out:
# fatal: destination path 'stylegan2-ada' already exists and is not an empty directory.
# Tensorflow version: 1.15.2
# Tue Nov  9 11:00:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    28W /  70W |    104MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# GPU Identified at: /device:GPU:0

# %% [markdown]
# ### 3-2. StyleGAN2 training function

# %%
os.chdir("/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/training")

# %%
# %%writefile training_loop.py

#@markdown Training loop settings
# # Total length of the training, measured in thousands of real images.
train_iterations = 10000 #@param {type:"number"}

# Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.

"""Main training loop."""

import os
import pickle
import time
import PIL.Image
import numpy as np
import tensorflow as tf
import dnnlib
import dnnlib.tflib as tflib
from dnnlib.tflib.autosummary import autosummary

from training import dataset

#----------------------------------------------------------------------------
# Select size and contents of the image snapshot grids that are exported
# periodically during training.

def setup_snapshot_image_grid(training_set):
    gw = np.clip(7680 // training_set.shape[2], 7, 32)
    gh = np.clip(4320 // training_set.shape[1], 4, 32)

    # Unconditional.
    if training_set.label_size == 0:
        reals, labels = training_set.get_minibatch_np(gw * gh)
        return (gw, gh), reals, labels

    # Row per class.
    cw, ch = (gw, 1)
    nw = (gw - 1) // cw + 1
    nh = (gh - 1) // ch + 1

    # Collect images.
    blocks = [[] for _i in range(nw * nh)]
    for _iter in range(1000000):
        real, label = training_set.get_minibatch_np(1)
        idx = np.argmax(label[0])
        while idx < len(blocks) and len(blocks[idx]) >= cw * ch:
            idx += training_set.label_size
        if idx < len(blocks):
            blocks[idx].append((real, label))
            if all(len(block) >= cw * ch for block in blocks):
                break

    # Layout grid.
    reals = np.zeros([gw * gh] + training_set.shape, dtype=training_set.dtype)
    labels = np.zeros([gw * gh, training_set.label_size], dtype=training_set.label_dtype)
    for i, block in enumerate(blocks):
        for j, (real, label) in enumerate(block):
            x = (i %  nw) * cw + j %  cw
            y = (i // nw) * ch + j // cw
            if x < gw and y < gh:
                reals[x + y * gw] = real[0]
                labels[x + y * gw] = label[0]
    return (gw, gh), reals, labels

#----------------------------------------------------------------------------

def save_image_grid(images, filename, drange, grid_size):
    lo, hi = drange
    gw, gh = grid_size
    images = np.asarray(images, dtype=np.float32)
    images = (images - lo) * (255 / (hi - lo))
    images = np.rint(images).clip(0, 255).astype(np.uint8)
    _N, C, H, W = images.shape
    images = images.reshape(gh, gw, C, H, W)
    images = images.transpose(0, 3, 1, 4, 2)
    images = images.reshape(gh * H, gw * W, C)
    PIL.Image.fromarray(images, {3: 'RGB', 1: 'L'}[C]).save(filename)

#----------------------------------------------------------------------------
# Main training script.

def training_loop(
    run_dir                 = '.',      # Output directory.
    G_args                  = {},       # Options for generator network.
    D_args                  = {},       # Options for discriminator network.
    G_opt_args              = {},       # Options for generator optimizer.
    D_opt_args              = {},       # Options for discriminator optimizer.
    loss_args               = {},       # Options for loss function.
    train_dataset_args      = {},       # Options for dataset to train with.
    metric_dataset_args     = {},       # Options for dataset to evaluate metrics against.
    augment_args            = {},       # Options for adaptive augmentations.
    metric_arg_list         = [],       # Metrics to evaluate during training.
    num_gpus                = 1,        # Number of GPUs to use.
    minibatch_size          = 32,       # Global minibatch size.
    minibatch_gpu           = 4,        # Number of samples processed at a time by one GPU.
    G_smoothing_kimg        = 10,       # Half-life of the exponential moving average (EMA) of generator weights.
    G_smoothing_rampup      = None,     # EMA ramp-up coefficient.
    minibatch_repeats       = 4,        # Number of minibatches to run in the inner loop.
    lazy_regularization     = True,     # Perform regularization as a separate training step?
    G_reg_interval          = 4,        # How often the perform regularization for G? Ignored if lazy_regularization=False.
    D_reg_interval          = 16,       # How often the perform regularization for D? Ignored if lazy_regularization=False.
    total_kimg              = train_iterations,    # Total length of the training, measured in thousands of real images.
    kimg_per_tick           = 10,        # Progress snapshot interval.
    image_snapshot_ticks    = 1,       # How often to save image snapshots? None = only save 'reals.png' and 'fakes-init.png'.
    network_snapshot_ticks  = 1,       # How often to save network snapshots? None = only save 'networks-final.pkl'.
    resume_pkl              = None,     # Network pickle to resume training from, None = train from scratch.
    resume_kimg             = 15000,      # Assumed training progress at the beginning. Affects reporting and training schedule.
    resume_time             = 0.0,      # Assumed wallclock time at the beginning. Affects reporting.
    abort_fn                = None,     # Callback function for determining whether to abort training.
    progress_fn             = None,     # Callback function for updating training progress.
):
    assert minibatch_size % (num_gpus * minibatch_gpu) == 0
    start_time = time.time()

    print('Loading training set...')
    training_set = dataset.load_dataset(**train_dataset_args)
    print('Image shape:', np.int32(training_set.shape).tolist())
    print('Label shape:', [training_set.label_size])
    print()

    print('Constructing networks...')
    with tf.device('/gpu:0'):
        G = tflib.Network('G', num_channels=training_set.shape[0], resolution=training_set.shape[1], label_size=training_set.label_size, **G_args)
        D = tflib.Network('D', num_channels=training_set.shape[0], resolution=training_set.shape[1], label_size=training_set.label_size, **D_args)
        Gs = G.clone('Gs')
        if resume_pkl is not None:
            print(f'Resuming from "{resume_pkl}"')
            with dnnlib.util.open_url(resume_pkl) as f:
                rG, rD, rGs = pickle.load(f)
            G.copy_vars_from(rG)
            D.copy_vars_from(rD)
            Gs.copy_vars_from(rGs)
    G.print_layers()
    D.print_layers()

    print('Exporting sample images...')
    grid_size, grid_reals, grid_labels = setup_snapshot_image_grid(training_set)
    save_image_grid(grid_reals, os.path.join(run_dir, 'reals.png'), drange=[0,255], grid_size=grid_size)
    grid_latents = np.random.randn(np.prod(grid_size), *G.input_shape[1:])
    grid_fakes = Gs.run(grid_latents, grid_labels, is_validation=True, minibatch_size=minibatch_gpu)
    save_image_grid(grid_fakes, os.path.join(run_dir, 'fakes_init.png'), drange=[-1,1], grid_size=grid_size)

    print(f'Replicating networks across {num_gpus} GPUs...')
    G_gpus = [G]
    D_gpus = [D]
    for gpu in range(1, num_gpus):
        with tf.device(f'/gpu:{gpu}'):
            G_gpus.append(G.clone(f'{G.name}_gpu{gpu}'))
            D_gpus.append(D.clone(f'{D.name}_gpu{gpu}'))

    print('Initializing augmentations...')
    aug = None
    if augment_args.get('class_name', None) is not None:
        aug = dnnlib.util.construct_class_by_name(**augment_args)
        aug.init_validation_set(D_gpus=D_gpus, training_set=training_set)

    print('Setting up optimizers...')
    G_opt_args = dict(G_opt_args)
    D_opt_args = dict(D_opt_args)
    for args, reg_interval in [(G_opt_args, G_reg_interval), (D_opt_args, D_reg_interval)]:
        args['minibatch_multiplier'] = minibatch_size // num_gpus // minibatch_gpu
        if lazy_regularization:
            mb_ratio = reg_interval / (reg_interval + 1)
            args['learning_rate'] *= mb_ratio
            if 'beta1' in args: args['beta1'] **= mb_ratio
            if 'beta2' in args: args['beta2'] **= mb_ratio
    G_opt = tflib.Optimizer(name='TrainG', **G_opt_args)
    D_opt = tflib.Optimizer(name='TrainD', **D_opt_args)
    G_reg_opt = tflib.Optimizer(name='RegG', share=G_opt, **G_opt_args)
    D_reg_opt = tflib.Optimizer(name='RegD', share=D_opt, **D_opt_args)

    print('Constructing training graph...')
    data_fetch_ops = []
    training_set.configure(minibatch_gpu)
    for gpu, (G_gpu, D_gpu) in enumerate(zip(G_gpus, D_gpus)):
        with tf.name_scope(f'Train_gpu{gpu}'), tf.device(f'/gpu:{gpu}'):

            # Fetch training data via temporary variables.
            with tf.name_scope('DataFetch'):
                real_images_var = tf.Variable(name='images', trainable=False, initial_value=tf.zeros([minibatch_gpu] + training_set.shape))
                real_labels_var = tf.Variable(name='labels', trainable=False, initial_value=tf.zeros([minibatch_gpu, training_set.label_size]))
                real_images_write, real_labels_write = training_set.get_minibatch_tf()
                real_images_write = tflib.convert_images_from_uint8(real_images_write)
                data_fetch_ops += [tf.assign(real_images_var, real_images_write)]
                data_fetch_ops += [tf.assign(real_labels_var, real_labels_write)]

            # Evaluate loss function and register gradients.
            fake_labels = training_set.get_random_labels_tf(minibatch_gpu)
            terms = dnnlib.util.call_func_by_name(G=G_gpu, D=D_gpu, aug=aug, fake_labels=fake_labels, real_images=real_images_var, real_labels=real_labels_var, **loss_args)
            if lazy_regularization:
                if terms.G_reg is not None: G_reg_opt.register_gradients(tf.reduce_mean(terms.G_reg * G_reg_interval), G_gpu.trainables)
                if terms.D_reg is not None: D_reg_opt.register_gradients(tf.reduce_mean(terms.D_reg * D_reg_interval), D_gpu.trainables)
            else:
                if terms.G_reg is not None: terms.G_loss += terms.G_reg
                if terms.D_reg is not None: terms.D_loss += terms.D_reg
            G_opt.register_gradients(tf.reduce_mean(terms.G_loss), G_gpu.trainables)
            D_opt.register_gradients(tf.reduce_mean(terms.D_loss), D_gpu.trainables)

    print('Finalizing training ops...')
    data_fetch_op = tf.group(*data_fetch_ops)
    G_train_op = G_opt.apply_updates()
    D_train_op = D_opt.apply_updates()
    G_reg_op = G_reg_opt.apply_updates(allow_no_op=True)
    D_reg_op = D_reg_opt.apply_updates(allow_no_op=True)
    Gs_beta_in = tf.placeholder(tf.float32, name='Gs_beta_in', shape=[])
    Gs_update_op = Gs.setup_as_moving_average_of(G, beta=Gs_beta_in)
    tflib.init_uninitialized_vars()
    with tf.device('/gpu:0'):
        peak_gpu_mem_op = tf.contrib.memory_stats.MaxBytesInUse()

    print('Initializing metrics...')
    summary_log = tf.summary.FileWriter(run_dir)
    metrics = []
    for args in metric_arg_list:
        metric = dnnlib.util.construct_class_by_name(**args)
        metric.configure(dataset_args=metric_dataset_args, run_dir=run_dir)
        metrics.append(metric)

    print(f'Training for {total_kimg} kimg...')
    print()
    if progress_fn is not None:
        progress_fn(0, total_kimg)
    tick_start_time = time.time()
    maintenance_time = tick_start_time - start_time
    cur_nimg = 0
    cur_tick = -1
    tick_start_nimg = cur_nimg
    running_mb_counter = 0

    done = False
    while not done:

        # Compute EMA decay parameter.
        Gs_nimg = G_smoothing_kimg * 1000.0
        if G_smoothing_rampup is not None:
            Gs_nimg = min(Gs_nimg, cur_nimg * G_smoothing_rampup)
        Gs_beta = 0.5 ** (minibatch_size / max(Gs_nimg, 1e-8))

        # Run training ops.
        for _repeat_idx in range(minibatch_repeats):
            rounds = range(0, minibatch_size, minibatch_gpu * num_gpus)
            run_G_reg = (lazy_regularization and running_mb_counter % G_reg_interval == 0)
            run_D_reg = (lazy_regularization and running_mb_counter % D_reg_interval == 0)
            cur_nimg += minibatch_size
            running_mb_counter += 1

            # Fast path without gradient accumulation.
            if len(rounds) == 1:
                tflib.run([G_train_op, data_fetch_op])
                if run_G_reg:
                    tflib.run(G_reg_op)
                tflib.run([D_train_op, Gs_update_op], {Gs_beta_in: Gs_beta})
                if run_D_reg:
                    tflib.run(D_reg_op)

            # Slow path with gradient accumulation.
            else:
                for _round in rounds:
                    tflib.run(G_train_op)
                    if run_G_reg:
                        tflib.run(G_reg_op)
                tflib.run(Gs_update_op, {Gs_beta_in: Gs_beta})
                for _round in rounds:
                    tflib.run(data_fetch_op)
                    tflib.run(D_train_op)
                    if run_D_reg:
                        tflib.run(D_reg_op)

            # Run validation.
            if aug is not None:
                aug.run_validation(minibatch_size=minibatch_size)

        # Tune augmentation parameters.
        if aug is not None:
            aug.tune(minibatch_size * minibatch_repeats)

        # Perform maintenance tasks once per tick.
        done = (cur_nimg >= total_kimg * 1000) or (abort_fn is not None and abort_fn())
        if done or cur_tick < 0 or cur_nimg >= tick_start_nimg + kimg_per_tick * 1000:
            cur_tick += 1
            tick_kimg = (cur_nimg - tick_start_nimg) / 1000.0
            tick_start_nimg = cur_nimg
            tick_end_time = time.time()
            total_time = tick_end_time - start_time
            tick_time = tick_end_time - tick_start_time

            # Report progress.
            print(' '.join([
                f"tick {autosummary('Progress/tick', cur_tick):<5d}",
                f"kimg {autosummary('Progress/kimg', cur_nimg / 1000.0):<8.1f}",
                f"time {dnnlib.util.format_time(autosummary('Timing/total_sec', total_time)):<12s}",
                f"sec/tick {autosummary('Timing/sec_per_tick', tick_time):<7.1f}",
                f"sec/kimg {autosummary('Timing/sec_per_kimg', tick_time / tick_kimg):<7.2f}",
                f"maintenance {autosummary('Timing/maintenance_sec', maintenance_time):<6.1f}",
                f"gpumem {autosummary('Resources/peak_gpu_mem_gb', peak_gpu_mem_op.eval() / 2**30):<5.1f}",
                f"augment {autosummary('Progress/augment', aug.strength if aug is not None else 0):.3f}",
            ]))
            autosummary('Timing/total_hours', total_time / (60.0 * 60.0))
            autosummary('Timing/total_days', total_time / (24.0 * 60.0 * 60.0))
            if progress_fn is not None:
                progress_fn(cur_nimg // 1000, total_kimg)

            # Save snapshots.
            if image_snapshot_ticks is not None and (done or cur_tick % image_snapshot_ticks == 0):
                grid_fakes = Gs.run(grid_latents, grid_labels, is_validation=True, minibatch_size=minibatch_gpu)
                save_image_grid(grid_fakes, os.path.join(run_dir, f'fakes{cur_nimg // 1000:06d}.png'), drange=[-1,1], grid_size=grid_size)

            if network_snapshot_ticks is not None and (done or cur_tick % network_snapshot_ticks == 0):
                pkl = os.path.join(run_dir, f'network-snapshot-{cur_nimg // 1000:06d}.pkl')
                with open(pkl, 'wb') as f:
                    pickle.dump((G, D, Gs), f)
                if len(metrics):
                    print('Evaluating metrics...')
                    for metric in metrics:
                        metric.run(pkl, num_gpus=num_gpus)

            # Update summaries.
            for metric in metrics:
                metric.update_autosummaries()
            tflib.autosummary.save_summaries(summary_log, cur_nimg)
            tick_start_time = time.time()
            maintenance_time = tick_start_time - tick_end_time

    print()
    print('Exiting...')
    summary_log.close()
    training_set.close()
# Out:
# Overwriting training_loop.py

# %%
os.chdir(stylegan2_ada)

# %%
result_path = "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/results/my_images"#@param{type: "string"}

#@markdown ---

# Training dataset (required): <path>
custom_dataset_path = '/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/custom'#@param{type: "string"}

#@markdown ---
# Load previous network
resume_training = '/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/results/my_images/00003-custom-mirror-stylegan2-kimg10000-ada-bgc-resumecustom/network-snapshot-000060.pkl'#@param{type: "string"}

#@markdown ---

# Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.

"""Train a GAN using the techniques described in the paper
"Training Generative Adversarial Networks with Limited Data"."""

import os
import argparse
import json
import re
import tensorflow as tf
import dnnlib
import dnnlib.tflib as tflib

from training import training_loop
from training import dataset
from metrics import metric_defaults

#----------------------------------------------------------------------------

class UserError(Exception):
    pass

#----------------------------------------------------------------------------

def setup_training_options():

###########################################################################################################################
#                                                 EDIT THESE!                                                             #
###########################################################################################################################
    outdir = result_path
    data = custom_dataset_path# Training dataset (required): <path>
    #resume = '/content/drive/MyDrive/NeuralNetworksTraining/StyleGan/StyleGAN2/surgery_output.pkl'# Load previous network: 'noresume' (default), 'ffhq256', 'ffhq512', 'ffhq1024', 'celebahq256', 'lsundog256', <file>, <url>
    resume = resume_training
    
    gpus = None # Number of GPUs: <int>, default = 1 gpu
    snap = 1 # Snapshot interval: <int>, default = 50 ticks
    seed = 1000

    res = None
    #res = None# Override dataset resolution: <int>, default = highest available 
    mirror =True# Augment dataset with x-flips: <bool>, default = False
    metrics = []# List of metric names: [], ['fid50k_full'] (default), ...
    metricdata = None# Metric dataset (optional): <path>
    cfg = 'stylegan2'# Base config: 'auto' (default), 'stylegan2', 'paper256', 'paper512', 'paper1024', 'cifar', 'cifarbaseline'
    gamma = None# Override R1 gamma: <float>, default = depends on cfg
    kimg = 10000# Override training duration: <int>, default = depends on cfg
    aug = 'ada' # Augmentation mode: 'ada' (default), 'noaug', 'fixed', 'adarv'
    p = None# Specify p for 'fixed' (required): <float>
    target = None # Override ADA target for 'ada' and 'adarv': <float>, default = depends on aug
    augpipe = 'bgc'# Augmentation pipeline: 'blit', 'geom', 'color', 'filter', 'noise', 'cutout', 'bg', 'bgc' (default), ..., 'bgcfnc'
    cmethod = None # Comparison method: 'nocmethod' (default), 'bcr', 'zcr', 'pagan', 'wgangp', 'auxrot', 'spectralnorm', 'shallowmap', 'adropout'
    dcap = None # Multiplier for discriminator capacity: <float>, default = 1
    augpipe = 'bgc'
    freezed = None # Freeze-D: <int>, default = 0 discriminator layers


###########################################################################################################################
#                                                 End of Edit Section                                                     #
###########################################################################################################################

    tflib.init_tf({'rnd.np_random_seed': seed})

    # Initialize dicts.
    args = dnnlib.EasyDict()
    args.G_args = dnnlib.EasyDict(func_name='training.networks.G_main')
    args.D_args = dnnlib.EasyDict(func_name='training.networks.D_main')
    args.G_opt_args = dnnlib.EasyDict(beta1=0.0, beta2=0.99)
    args.D_opt_args = dnnlib.EasyDict(beta1=0.0, beta2=0.99)
    args.loss_args = dnnlib.EasyDict(func_name='training.loss.stylegan2')
    args.augment_args = dnnlib.EasyDict(class_name='training.augment.AdaptiveAugment')

    # ---------------------------
    # General options: gpus, snap
    # ---------------------------

    if gpus is None:
        gpus = 1
    assert isinstance(gpus, int)
    if not (gpus >= 1 and gpus & (gpus - 1) == 0):
        raise UserError('--gpus must be a power of two')
    args.num_gpus = gpus

    if snap is None:
        snap = 50
    assert isinstance(snap, int)
    if snap < 1:
        raise UserError('--snap must be at least 1')
    args.image_snapshot_ticks = snap
    args.network_snapshot_ticks = snap

    # -----------------------------------
    # Training dataset: data, res, mirror
    # -----------------------------------

    assert data is not None
    assert isinstance(data, str)
    data_name = os.path.basename(os.path.abspath(data))
    if not os.path.isdir(data) or len(data_name) == 0:
        raise UserError('--data must point to a directory containing *.tfrecords')
    desc = data_name

    with tf.Graph().as_default(), tflib.create_session().as_default(): # pylint: disable=not-context-manager
        args.train_dataset_args = dnnlib.EasyDict(path=data, max_label_size='full')
        dataset_obj = dataset.load_dataset(**args.train_dataset_args) # try to load the data and see what comes out
        args.train_dataset_args.resolution = dataset_obj.shape[-1] # be explicit about resolution
        args.train_dataset_args.max_label_size = dataset_obj.label_size # be explicit about label size
        validation_set_available = dataset_obj.has_validation_set
        dataset_obj.close()
        dataset_obj = None

    if res is None:
        res = args.train_dataset_args.resolution
    else:
        assert isinstance(res, int)
        if not (res >= 4 and res & (res - 1) == 0):
            raise UserError('--res must be a power of two and at least 4')
        if res > args.train_dataset_args.resolution:
            raise UserError(f'--res cannot exceed maximum available resolution in the dataset ({args.train_dataset_args.resolution})')
        desc += f'-res{res:d}'
    args.train_dataset_args.resolution = res

    if mirror is None:
        mirror = False
    else:
        assert isinstance(mirror, bool)
        if mirror:
            desc += '-mirror'
    args.train_dataset_args.mirror_augment = mirror

    # ----------------------------
    # Metrics: metrics, metricdata
    # ----------------------------

    if metrics is None:
        metrics = ['fid50k_full']
    assert isinstance(metrics, list)
    assert all(isinstance(metric, str) for metric in metrics)

    args.metric_arg_list = []
    for metric in metrics:
        if metric not in metric_defaults.metric_defaults:
            raise UserError('\n'.join(['--metrics can only contain the following values:', 'none'] + list(metric_defaults.metric_defaults.keys())))
        args.metric_arg_list.append(metric_defaults.metric_defaults[metric])

    args.metric_dataset_args = dnnlib.EasyDict(args.train_dataset_args)
    if metricdata is not None:
        assert isinstance(metricdata, str)
        if not os.path.isdir(metricdata):
            raise UserError('--metricdata must point to a directory containing *.tfrecords')
        args.metric_dataset_args.path = metricdata

    # -----------------------------
    # Base config: cfg, gamma, kimg
    # -----------------------------

    if cfg is None:
        cfg = 'auto'
    assert isinstance(cfg, str)
    desc += f'-{cfg}'

    cfg_specs = {
        'auto':          dict(ref_gpus=-1, kimg=25000,  mb=-1, mbstd=-1, fmaps=-1,  lrate=-1,     gamma=-1,   ema=-1,  ramp=0.05, map=2), # populated dynamically based on 'gpus' and 'res'
        'stylegan2':     dict(ref_gpus=8,  kimg=25000,  mb=32, mbstd=4,  fmaps=1,   lrate=0.002,  gamma=10,   ema=10,  ramp=None, map=8), # uses mixed-precision, unlike original StyleGAN2
        'paper256':      dict(ref_gpus=8,  kimg=25000,  mb=64, mbstd=8,  fmaps=0.5, lrate=0.0025, gamma=1,    ema=20,  ramp=None, map=8),
        'paper512':      dict(ref_gpus=8,  kimg=25000,  mb=64, mbstd=8,  fmaps=1,   lrate=0.0025, gamma=0.5,  ema=20,  ramp=None, map=8),
        'paper1024':     dict(ref_gpus=8,  kimg=25000,  mb=32, mbstd=4,  fmaps=1,   lrate=0.002,  gamma=2,    ema=10,  ramp=None, map=8),
        'cifar':         dict(ref_gpus=2,  kimg=100000, mb=64, mbstd=32, fmaps=0.5, lrate=0.0025, gamma=0.01, ema=500, ramp=0.05, map=2),
        'cifarbaseline': dict(ref_gpus=2,  kimg=100000, mb=64, mbstd=32, fmaps=0.5, lrate=0.0025, gamma=0.01, ema=500, ramp=0.05, map=8),
    }

    assert cfg in cfg_specs
    spec = dnnlib.EasyDict(cfg_specs[cfg])
    if cfg == 'auto':
        desc += f'{gpus:d}'
        spec.ref_gpus = gpus
        spec.mb = max(min(gpus * min(4096 // res, 32), 64), gpus) # keep gpu memory consumption at bay
        spec.mbstd = min(spec.mb // gpus, 4) # other hyperparams behave more predictably if mbstd group size remains fixed
        spec.fmaps = 1 if res >= 512 else 0.5
        spec.lrate = 0.002 if res >= 1024 else 0.0025
        spec.gamma = 0.0002 * (res ** 2) / spec.mb # heuristic formula
        spec.ema = spec.mb * 10 / 32

    args.total_kimg = spec.kimg
    args.minibatch_size = spec.mb
    args.minibatch_gpu = spec.mb // spec.ref_gpus
    args.D_args.mbstd_group_size = spec.mbstd
    args.G_args.fmap_base = args.D_args.fmap_base = int(spec.fmaps * 16384)
    args.G_args.fmap_max = args.D_args.fmap_max = 512
    args.G_opt_args.learning_rate = args.D_opt_args.learning_rate = spec.lrate
    args.loss_args.r1_gamma = spec.gamma
    args.G_smoothing_kimg = spec.ema
    args.G_smoothing_rampup = spec.ramp
    args.G_args.mapping_layers = spec.map
    args.G_args.num_fp16_res = args.D_args.num_fp16_res = 4 # enable mixed-precision training
    args.G_args.conv_clamp = args.D_args.conv_clamp = 256 # clamp activations to avoid float16 overflow

    if cfg == 'cifar':
        args.loss_args.pl_weight = 0 # disable path length regularization
        args.G_args.style_mixing_prob = None # disable style mixing
        args.D_args.architecture = 'orig' # disable residual skip connections

    if gamma is not None:
        assert isinstance(gamma, float)
        if not gamma >= 0:
            raise UserError('--gamma must be non-negative')
        desc += f'-gamma{gamma:g}'
        args.loss_args.r1_gamma = gamma

    if kimg is not None:
        assert isinstance(kimg, int)
        if not kimg >= 1:
            raise UserError('--kimg must be at least 1')
        desc += f'-kimg{kimg:d}'
        args.total_kimg = kimg

    # ---------------------------------------------------
    # Discriminator augmentation: aug, p, target, augpipe
    # ---------------------------------------------------

    if aug is None:
        aug = 'ada'
    else:
        assert isinstance(aug, str)
        desc += f'-{aug}'

    if aug == 'ada':
        args.augment_args.tune_heuristic = 'rt'
        args.augment_args.tune_target = 0.6

    elif aug == 'noaug':
        pass

    elif aug == 'fixed':
        if p is None:
            raise UserError(f'--aug={aug} requires specifying --p')

    elif aug == 'adarv':
        if not validation_set_available:
            raise UserError(f'--aug={aug} requires separate validation set; please see "python dataset_tool.py pack -h"')
        args.augment_args.tune_heuristic = 'rv'
        args.augment_args.tune_target = 0.5

    else:
        raise UserError(f'--aug={aug} not supported')

    if p is not None:
        assert isinstance(p, float)
        if aug != 'fixed':
            raise UserError('--p can only be specified with --aug=fixed')
        if not 0 <= p <= 1:
            raise UserError('--p must be between 0 and 1')
        desc += f'-p{p:g}'
        args.augment_args.initial_strength = p

    if target is not None:
        assert isinstance(target, float)
        if aug not in ['ada', 'adarv']:
            raise UserError('--target can only be specified with --aug=ada or --aug=adarv')
        if not 0 <= target <= 1:
            raise UserError('--target must be between 0 and 1')
        desc += f'-target{target:g}'
        args.augment_args.tune_target = target

    assert augpipe is None or isinstance(augpipe, str)
    if augpipe is None:
        augpipe = 'bgc'
    else:
        if aug == 'noaug':
            raise UserError('--augpipe cannot be specified with --aug=noaug')
        desc += f'-{augpipe}'

    augpipe_specs = {
        'blit':     dict(xflip=1, rotate90=1, xint=1),
        'geom':     dict(scale=1, rotate=1, aniso=1, xfrac=1),
        'color':    dict(brightness=1, contrast=1, lumaflip=1, hue=1, saturation=1),
        'filter':   dict(imgfilter=1),
        'noise':    dict(noise=1),
        'cutout':   dict(cutout=1),
        'bg':       dict(xflip=1, rotate90=1, xint=1, scale=1, rotate=1, aniso=1, xfrac=1),
        'bgc':      dict(xflip=1, rotate90=1, xint=1, scale=1, rotate=1, aniso=1, xfrac=1, brightness=1, contrast=1, lumaflip=1, hue=1, saturation=1),
        'bgcf':     dict(xflip=1, rotate90=1, xint=1, scale=1, rotate=1, aniso=1, xfrac=1, brightness=1, contrast=1, lumaflip=1, hue=1, saturation=1, imgfilter=1),
        'bgcfn':    dict(xflip=1, rotate90=1, xint=1, scale=1, rotate=1, aniso=1, xfrac=1, brightness=1, contrast=1, lumaflip=1, hue=1, saturation=1, imgfilter=1, noise=1),
        'bgcfnc':   dict(xflip=1, rotate90=1, xint=1, scale=1, rotate=1, aniso=1, xfrac=1, brightness=1, contrast=1, lumaflip=1, hue=1, saturation=1, imgfilter=1, noise=1, cutout=1),
    }

    assert augpipe in augpipe_specs
    if aug != 'noaug':
        args.augment_args.apply_func = 'training.augment.augment_pipeline'
        args.augment_args.apply_args = augpipe_specs[augpipe]

    # ---------------------------------
    # Comparison methods: cmethod, dcap
    # ---------------------------------

    assert cmethod is None or isinstance(cmethod, str)
    if cmethod is None:
        cmethod = 'nocmethod'
    else:
        desc += f'-{cmethod}'

    if cmethod == 'nocmethod':
        pass

    elif cmethod == 'bcr':
        args.loss_args.func_name = 'training.loss.cmethods'
        args.loss_args.bcr_real_weight = 10
        args.loss_args.bcr_fake_weight = 10
        args.loss_args.bcr_augment = dnnlib.EasyDict(func_name='training.augment.augment_pipeline', xint=1, xint_max=1/32)

    elif cmethod == 'zcr':
        args.loss_args.func_name = 'training.loss.cmethods'
        args.loss_args.zcr_gen_weight = 0.02
        args.loss_args.zcr_dis_weight = 0.2
        args.G_args.num_fp16_res = args.D_args.num_fp16_res = 0 # disable mixed-precision training
        args.G_args.conv_clamp = args.D_args.conv_clamp = None

    elif cmethod == 'pagan':
        if aug != 'noaug':
            raise UserError(f'--cmethod={cmethod} is not compatible with discriminator augmentation; please specify --aug=noaug')
        args.D_args.use_pagan = True
        args.augment_args.tune_heuristic = 'rt' # enable ada heuristic
        args.augment_args.pop('apply_func', None) # disable discriminator augmentation
        args.augment_args.pop('apply_args', None)
        args.augment_args.tune_target = 0.95

    elif cmethod == 'wgangp':
        if aug != 'noaug':
            raise UserError(f'--cmethod={cmethod} is not compatible with discriminator augmentation; please specify --aug=noaug')
        if gamma is not None:
            raise UserError(f'--cmethod={cmethod} is not compatible with --gamma')
        args.loss_args = dnnlib.EasyDict(func_name='training.loss.wgangp')
        args.G_opt_args.learning_rate = args.D_opt_args.learning_rate = 0.001
        args.G_args.num_fp16_res = args.D_args.num_fp16_res = 0 # disable mixed-precision training
        args.G_args.conv_clamp = args.D_args.conv_clamp = None
        args.lazy_regularization = False

    elif cmethod == 'auxrot':
        if args.train_dataset_args.max_label_size > 0:
            raise UserError(f'--cmethod={cmethod} is not compatible with label conditioning; please specify a dataset without labels')
        args.loss_args.func_name = 'training.loss.cmethods'
        args.loss_args.auxrot_alpha = 10
        args.loss_args.auxrot_beta = 5
        args.D_args.score_max = 5 # prepare D to output 5 scalars per image instead of just 1

    elif cmethod == 'spectralnorm':
        args.D_args.use_spectral_norm = True

    elif cmethod == 'shallowmap':
        if args.G_args.mapping_layers == 2:
            raise UserError(f'--cmethod={cmethod} is a no-op for --cfg={cfg}')
        args.G_args.mapping_layers = 2

    elif cmethod == 'adropout':
        if aug != 'noaug':
            raise UserError(f'--cmethod={cmethod} is not compatible with discriminator augmentation; please specify --aug=noaug')
        args.D_args.adaptive_dropout = 1
        args.augment_args.tune_heuristic = 'rt' # enable ada heuristic
        args.augment_args.pop('apply_func', None) # disable discriminator augmentation
        args.augment_args.pop('apply_args', None)
        args.augment_args.tune_target = 0.6

    else:
        raise UserError(f'--cmethod={cmethod} not supported')

    if dcap is not None:
        assert isinstance(dcap, float)
        if not dcap > 0:
            raise UserError('--dcap must be positive')
        desc += f'-dcap{dcap:g}'
        args.D_args.fmap_base = max(int(args.D_args.fmap_base * dcap), 1)
        args.D_args.fmap_max = max(int(args.D_args.fmap_max * dcap), 1)

    # ----------------------------------
    # Transfer learning: resume, freezed
    # ----------------------------------

    resume_specs = {
        'ffhq256':      'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl',
        'ffhq512':      'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/ffhq-res512-mirror-stylegan2-noaug.pkl',
        'ffhq1024':     'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/ffhq-res1024-mirror-stylegan2-noaug.pkl',
        'celebahq256':  'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/celebahq-res256-mirror-paper256-kimg100000-ada-target0.5.pkl',
        'lsundog256':   'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/lsundog-res256-paper256-kimg100000-noaug.pkl',
    }

    assert resume is None or isinstance(resume, str)
    if resume is None:
        resume = 'noresume'
    elif resume == 'noresume':
        desc += '-noresume'
    elif resume in resume_specs:
        desc += f'-resume{resume}'
        args.resume_pkl = resume_specs[resume] # predefined url
    else:
        desc += '-resumecustom'
        args.resume_pkl = resume # custom path or url

    if resume != 'noresume':
        args.augment_args.tune_kimg = 100 # make ADA react faster at the beginning
        args.G_smoothing_rampup = None # disable EMA rampup

    if freezed is not None:
        assert isinstance(freezed, int)
        if not freezed >= 0:
            raise UserError('--freezed must be non-negative')
        desc += f'-freezed{freezed:d}'
        args.D_args.freeze_layers = freezed

    return desc, args, outdir

#----------------------------------------------------------------------------

def run_training():

    run_desc, training_options, outdir = setup_training_options()

    # Pick output directory.
    prev_run_dirs = []
    if os.path.isdir(outdir):
        prev_run_dirs = [x for x in os.listdir(outdir) if os.path.isdir(os.path.join(outdir, x))]
    prev_run_ids = [re.match(r'^\d+', x) for x in prev_run_dirs]
    prev_run_ids = [int(x.group()) for x in prev_run_ids if x is not None]
    cur_run_id = max(prev_run_ids, default=-1) + 1
    training_options.run_dir = os.path.join(outdir, f'{cur_run_id:05d}-{run_desc}')
    assert not os.path.exists(training_options.run_dir)

    # Print options.
    print()
    print('Training options:')
    print(json.dumps(training_options, indent=2))
    print()
    print(f'Output directory:  {training_options.run_dir}')
    print(f'Training data:     {training_options.train_dataset_args.path}')
    print(f'Training length:   {training_options.total_kimg} kimg')
    print(f'Resolution:        {training_options.train_dataset_args.resolution}')
    print(f'Number of GPUs:    {training_options.num_gpus}')
    print()

    # Kick off training.
    print('Creating output directory...')
    os.makedirs(training_options.run_dir)
    with open(os.path.join(training_options.run_dir, 'training_options.json'), 'wt') as f:
        json.dump(training_options, f, indent=2)
    with dnnlib.util.Logger(os.path.join(training_options.run_dir, 'log.txt')):
        training_loop.training_loop(**training_options)

#----------------------------------------------------------------------------

def _str_to_bool(v):
    if isinstance(v, bool):
        return v
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    if v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    raise argparse.ArgumentTypeError('Boolean value expected.')

def _parse_comma_sep(s):
    if s is None or s.lower() == 'none' or s == '':
        return []
    return s.split(',')

def main():
    run_training()

#----------------------------------------------------------------------------

if __name__ == "__main__":
    main()

#----------------------------------------------------------------------------
# Out:
# WARNING: Entity <function TFRecordDataset.parse_tfrecord_tf at 0x7fe6b68a0290> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
#
# Training options:
# {
#   "G_args": {
#     "func_name": "training.networks.G_main",
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "mapping_layers": 8,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "D_args": {
#     "func_name": "training.networks.D_main",
#     "mbstd_group_size": 4,
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.002
#   },
#   "D_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.002
#   },
#   "loss_args": {
#     "func_name": "training.loss.stylegan2",
#     "r1_gamma": 10
#   },
#   "augment_args": {
#     "class_name": "training.augment.AdaptiveAugment",
#     "tune_heuristic": "rt",
#     "tune_target": 0.6,
#     "apply_func": "training.augment.augment_pipeline",
#     "apply_args": {
#       "xflip": 1,
#       "rotate90": 1,
#       "xint": 1,
#       "scale": 1,
#       "rotate": 1,
#       "aniso": 1,
#       "xfrac": 1,
#       "brightness": 1,
#       "contrast": 1,
#       "lumaflip": 1,
#       "hue": 1,
#       "saturation": 1
#     },
#     "tune_kimg": 100
#   },
#   "num_gpus": 1,
#   "image_snapshot_ticks": 1,
#   "network_snapshot_ticks": 1,
#   "train_dataset_args": {
#     "path": "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/custom",
#     "max_label_size": 0,
#     "resolution": 1024,
#     "mirror_augment": true
#   },
#   "metric_arg_list": [],
#   "metric_dataset_args": {
#     "path": "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/custom",
#     "max_label_size": 0,
#     "resolution": 1024,
#     "mirror_augment": true
#   },
#   "total_kimg": 10000,
#   "minibatch_size": 32,
#   "minibatch_gpu": 4,
#   "G_smoothing_kimg": 10,
#   "G_smoothing_rampup": null,
#   "resume_pkl": "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/results/my_images/00003-custom-mirror-stylegan2-kimg10000-ada-bgc-resumecustom/network-snapshot-000060.pkl",
#   "run_dir": "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/results/my_images/00004-custom-mirror-stylegan2-kimg10000-ada-bgc-resumecustom"
# }
#
# Output directory:  /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/results/my_images/00004-custom-mirror-stylegan2-kimg10000-ada-bgc-resumecustom
# Training data:     /content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/datasets/custom
# Training length:   10000 kimg
# Resolution:        1024
# Number of GPUs:    1
#
# Creating output directory...
# Loading training set...
# Image shape: [3, 1024, 1024]
# Label shape: [0]
#
# Constructing networks...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
# Resuming from "/content/drive/MyDrive/Deep_Architecture_using_AI_in_architecture/colab-sg2-ada/stylegan2-ada/results/my_images/00003-custom-mirror-stylegan2-kimg10000-ada-bgc-resumecustom/network-snapshot-000060.pkl"
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# epochs                          1         ()                   ()
# epochs_1                        1         ()                   ()
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# dlatent_avg                     -         (512,)               -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# ---                             ---       ---                  ---
# Total                           30370062
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# ---                   ---       ---                  ---
# Total                 29012513
#
# Exporting sample images...
# Replicating networks across 1 GPUs...
# Initializing augmentations...
# Setting up optimizers...
# Constructing training graph...
# Finalizing training ops...
# Initializing metrics...
# Training for 10000 kimg...
#
# tick 0     kimg 0.1      time 7m 11s       sec/tick 170.2   sec/kimg 1329.43 maintenance 260.8  gpumem 10.3  augment 0.001
# tick 1     kimg 10.2     time 1h 52m 29s   sec/tick 6292.7  sec/kimg 622.30  maintenance 25.6   gpumem 10.3  augment 0.077
